# %% [markdown]
# ### Project Team Id : PTID-CDS-FEB-24-1819

# %% [markdown]
# ### Project Code : PRCP -1024

# %% [markdown]
# ### Texas Employee Salary  Prediction

# %% [markdown]
# ## **Business Case** : To predict a salary of employees based on the given features.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# ### Task 1:-
# ### Prepare a complete data analysis report on the given data.

# %% [markdown]
# ### Task 2:-
# ### Create a predictive model which will help theTexas state government  team to know the payroll information of employees of the state of Texas.

# %% [markdown]
# ### Task 3:-
# ### ●	Who are the outliers in the salaries?
# ### ●	What departments/roles have the biggest wage disparities between managers and employees?
# ### ●	Have salaries and total compensations for some roles/ departments/ head-count changed over time?

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read the given dataset

# %%
df=pd.read_csv(r"C:\Users\satka\Downloads\salary\salary.csv",low_memory=False)
df
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# ...

# %% [markdown]
# # Task 1:-Prepare a complete data analysis report on the given data.

# %% [markdown]
# ## Basic checks

# %%
df.head()
# Out:
#    AGENCY                                        AGENCY NAME  \
# 0     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1     212  OFFICE OF COURT ADMINISTRATION                ...
# 2     241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3     212  OFFICE OF COURT ADMINISTRATION                ...
# 4     696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
#
#                         LAST NAME                      FIRST NAME MI  \
# 0  RUCKER                          MORTON                          V
# 1  RUCKER                          MORTON                          V
# 2  SPECIA JR                       JOHN                            J
# 3  SPECIA JR                       JOHN                            J
# 4  ONTIVEROS                       ESTHER
#
#   CLASS CODE                                        CLASS TITLE  \
# 0   JD25      JUDGE, RETIRED                                ...
# 1   3524      GENERAL COUNSEL IV                            ...
# ...

# %%
df.tail()
# Out:
#         AGENCY                                        AGENCY NAME  \
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 149476  WESSELS                         JOHN                            P
# 149477  WINDHAM                         EVAN                            A
# 149478  WRIGHT                          DERRICK                         C
# 149479  YOUNG                           DOUGLAS                         R
# 149480  ZUNKER                          GEORGIA                         P
#
#        CLASS CODE                                        CLASS TITLE  \
# ...

# %% [markdown]
# There are missing values in duplicated, multiple_full_time_jobs, combined_multiple_jobs, summed_annual_salary, hide_from_search. So, We need to remove all the missing values present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149481 entries, 0 to 149480
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   AGENCY                   149481 non-null  int64
#  1   AGENCY NAME              149481 non-null  object
#  2   LAST NAME                149481 non-null  object
#  3   FIRST NAME               149481 non-null  object
#  4   MI                       149481 non-null  object
#  5   CLASS CODE               149481 non-null  object
#  6   CLASS TITLE              149481 non-null  object
#  7   ETHNICITY                149481 non-null  object
#  8   GENDER                   149481 non-null  object
#  9   STATUS                   149481 non-null  object
#  10  EMPLOY DATE              149481 non-null  object
#  11  HRLY RATE                149481 non-null  float64
#  12  HRS PER WK               149481 non-null  float64
# ...

# %% [markdown]
# There are null values in multiple_full_time_jobs, combined_multiple_jobs, summed_annual_salary, hide_from_search. So, We need to remove all the null values present in the dataset.

# %%
df.isnull().sum()
# Out:
# AGENCY                          0
# AGENCY NAME                     0
# LAST NAME                       0
# FIRST NAME                      0
# MI                              0
# CLASS CODE                      0
# CLASS TITLE                     0
# ETHNICITY                       0
# GENDER                          0
# STATUS                          0
# EMPLOY DATE                     0
# HRLY RATE                       0
# HRS PER WK                      0
# MONTHLY                         0
# ANNUAL                          0
# STATE NUMBER                    0
# duplicated                 149338
# multiple_full_time_jobs    149467
# combined_multiple_jobs     149384
# summed_annual_salary       149465
# hide_from_search           149465
# dtype: int64

# %%
df.describe(include='O')
# Out:
#                                               AGENCY NAME  \
# count                                              149481
# unique                                                113
# top     HEALTH AND HUMAN SERVICES COMMISSION          ...
# freq                                                36667
#
#                              LAST NAME                      FIRST NAME  \
# count                           149481                          149481
# unique                           38675                           23559
# top     SMITH                           MICHAEL
# freq                              1243                            1843
#
#             MI CLASS CODE                                        CLASS TITLE  \
# count   149481     149481                                             149481
# unique      27       1481                                               1422
# top              4504      CORREC  OFFICER IV                            ...
# ...

# %% [markdown]
# Here the EMPLOY DATE is in object type, so firstly we need to convert this into proper date type for proper prediction.

# %%
df.dtypes
# Out:
# AGENCY                       int64
# AGENCY NAME                 object
# LAST NAME                   object
# FIRST NAME                  object
# MI                          object
# CLASS CODE                  object
# CLASS TITLE                 object
# ETHNICITY                   object
# GENDER                      object
# STATUS                      object
# EMPLOY DATE                 object
# HRLY RATE                  float64
# HRS PER WK                 float64
# MONTHLY                    float64
# ANNUAL                     float64
# STATE NUMBER                 int64
# duplicated                  object
# multiple_full_time_jobs    float64
# combined_multiple_jobs      object
# summed_annual_salary       float64
# hide_from_search            object
# dtype: object

# %%
df1=df.copy()

# %% [markdown]
# Here we copied the dataset into another dataframe because we dont want to disturb the actual data.

# %%
df1
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# ...

# %% [markdown]
# ### Dropping unwanted columns from the dataset

# %% [markdown]
# We are Dropping the unwanted columns from the Dataset which are unneccessary for the model implementation. There are many missing values present in those columns, As it may make affect on model prediction. So we are Dropping those columns.

# %%
df1.drop(columns='duplicated',axis=1,inplace=True)

# %%
df1.drop(columns='multiple_full_time_jobs',axis=1,inplace=True)

# %%
df1.drop(columns='combined_multiple_jobs',axis=1,inplace=True)

# %%
df1.drop(columns='summed_annual_salary',axis=1,inplace=True)

# %%
df1.drop(columns='hide_from_search',axis=1,inplace=True)

# %%
df1.drop(columns='STATE NUMBER',axis=1,inplace=True)
df1
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# ...

# %%
df1[df1.duplicated()].shape
# Out:
# (0, 15)

# %% [markdown]
# ### Dropping duplicates from the dataset

# %%
df1 = df1.drop_duplicates(keep = 'first')
df1
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# ...

# %% [markdown]
# ### Missing/Null values in each column

# %%
df1.isnull().sum()
# Out:
# AGENCY         0
# AGENCY NAME    0
# LAST NAME      0
# FIRST NAME     0
# MI             0
# CLASS CODE     0
# CLASS TITLE    0
# ETHNICITY      0
# GENDER         0
# STATUS         0
# EMPLOY DATE    0
# HRLY RATE      0
# HRS PER WK     0
# MONTHLY        0
# ANNUAL         0
# dtype: int64

# %% [markdown]
# ### Size of the data after dropping the duplicate

# %%
df1.shape
# Out:
# (149481, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149481 entries, 0 to 149480
# Data columns (total 15 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   AGENCY       149481 non-null  int64
#  1   AGENCY NAME  149481 non-null  object
#  2   LAST NAME    149481 non-null  object
#  3   FIRST NAME   149481 non-null  object
#  4   MI           149481 non-null  object
#  5   CLASS CODE   149481 non-null  object
#  6   CLASS TITLE  149481 non-null  object
#  7   ETHNICITY    149481 non-null  object
#  8   GENDER       149481 non-null  object
#  9   STATUS       149481 non-null  object
#  10  EMPLOY DATE  149481 non-null  object
#  11  HRLY RATE    149481 non-null  float64
#  12  HRS PER WK   149481 non-null  float64
#  13  MONTHLY      149481 non-null  float64
#  14  ANNUAL       149481 non-null  float64
# dtypes: float64(4), int64(1), object(10)
# memory usage: 17.1+ MB

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Statistics of Numerical Columns

# %%
df1.describe()
# Out:
#               AGENCY      HRLY RATE     HRS PER WK        MONTHLY  \
# count  149481.000000  149481.000000  149481.000000  149481.000000
# mean      545.736288       0.346488      39.714918    4226.184248
# std       139.057691       4.211485       2.323855    2093.111691
# min       101.000000       0.000000       1.000000      50.000000
# 25%       529.000000       0.000000      40.000000    3019.840000
# 50%       530.000000       0.000000      40.000000    3720.170000
# 75%       696.000000       0.000000      40.000000    4865.810000
# max       930.000000     117.788480      70.000000   46125.000000
#
#               ANNUAL
# count  149481.000000
# mean    50714.210973
# std     25117.340292
# min       600.000000
# 25%     36238.080000
# 50%     44642.040000
# 75%     58389.720000
# max    553500.000000

# %%
df1.describe(include='O')
# Out:
#                                               AGENCY NAME  \
# count                                              149481
# unique                                                113
# top     HEALTH AND HUMAN SERVICES COMMISSION          ...
# freq                                                36667
#
#                              LAST NAME                      FIRST NAME  \
# count                           149481                          149481
# unique                           38675                           23559
# top     SMITH                           MICHAEL
# freq                              1243                            1843
#
#             MI CLASS CODE                                        CLASS TITLE  \
# count   149481     149481                                             149481
# unique      27       1481                                               1422
# top              4504      CORREC  OFFICER IV                            ...
# ...

# %% [markdown]
# ### Co-relation Matrix among Numerical Features

# %%
import seaborn as sns
corr = df[['HRLY RATE','HRS PER WK','MONTHLY','ANNUAL']].corr()
sns.heatmap(corr.corr(),cmap='crest',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Correlation between Monthly and Annual is 1, so we can drop one of these columns.

# %%
df1.drop(columns='ANNUAL',axis=1,inplace=True)

# %%
# !pip install sweetviz
# Out:
# ...
#   Obtaining dependency information for sweetviz from https://files.pythonhosted.org/packages/89/50/8d3f7ca820267a38b42c64778db0f186d85cec6e3f0c5210eab9c16e783f/sweetviz-2.3.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for importlib-resources>=1.2.0 from https://files.pythonhosted.org/packages/de/79/7ad3b2831247db4f61e781f9164147b1ee20205c5230dcd177021caa266b/importlib_resources-6.3.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.1 MB 3.2 MB/s eta 0:00:05
#     --------------------------------------- 0.3/15.1 MB 3.2 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/15.1 MB 3.4 MB/s eta 0:00:05
#    - -------------------------------------- 0.5/15.1 MB 3.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.8/15.1 MB 3.8 MB/s eta 0:00:04
#    -- ------------------------------------- 1.1/15.1 MB 4.0 MB/s eta 0:00:04
# ...

# %%
import sweetviz as sv
#syntax to use sweetviz
my_report=sv.analyze(df1)
#default arguments will generate to 'Sweetviz_report.html'
my_report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Converting Categorical into Numerical Columns

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
df1
# Out:
#         AGENCY                                        AGENCY NAME  \
# 0          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 1          212  OFFICE OF COURT ADMINISTRATION                ...
# 2          241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...
# 3          212  OFFICE OF COURT ADMINISTRATION                ...
# 4          696  TEXAS DEPARTMENT OF CRIMINAL JUSTICE          ...
# ...        ...                                                ...
# 149476     809  STATE PRESERVATION BOARD                      ...
# 149477     809  STATE PRESERVATION BOARD                      ...
# 149478     809  STATE PRESERVATION BOARD                      ...
# 149479     809  STATE PRESERVATION BOARD                      ...
# 149480     809  STATE PRESERVATION BOARD                      ...
#
#                              LAST NAME                      FIRST NAME MI  \
# 0       RUCKER                          MORTON                          V
# ...

# %%
df1['AGENCY NAME'] = le.fit_transform(df1['AGENCY NAME'])
df1['LAST NAME'] = le.fit_transform(df1['LAST NAME'])
df1['FIRST NAME'] = le.fit_transform(df1['FIRST NAME'])
df1['MI'] = le.fit_transform(df1['MI'])
df1['CLASS TITLE'] = le.fit_transform(df1['CLASS TITLE'])
df1['STATUS'] = le.fit_transform(df1['STATUS'])
df1['ETHNICITY'] = le.fit_transform(df1['ETHNICITY'])
df1['GENDER'] = le.fit_transform(df1['GENDER'])
df1['CLASS CODE'] = le.fit_transform(df1['CLASS CODE'])

# %% [markdown]
# Here in this data every Categorical Columns converted into Numerical Columns

# %%
df1
# Out:
#         AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  \
# 0          241           17      30461       15274  22        1409
# 1          212           48      30461       15274  22         616
# 2          241           17      33197       10053  10        1409
# 3          212           48      33197       10053  10         616
# 4          696           88      26462        6953   0         810
# ...        ...          ...        ...         ...  ..         ...
# 149476     809           76      37355       10053  16        1042
# 149477     809           76      37780        7024   1          84
# 149478     809           76      38068        5571   3           4
# 149479     809           76      38313        6089  18         278
# 149480     809           76      38652        7720  16           4
#
#         CLASS TITLE  ETHNICITY  GENDER  STATUS EMPLOY DATE  HRLY RATE  \
# 0               711          5       1       8    02/18/88   75.96150
# ...

# %%
# Assuming 'EMPLOY DATE' is the column containing dates in string format
df1['EMPLOY DATE'] = pd.to_datetime(df1['EMPLOY DATE'])

# Extract numerical components like year, month, day, etc.
df1['month'] = df1['EMPLOY DATE'].dt.month

# Display the modified DataFrame
df1.head()
# Out:
#    AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  CLASS TITLE  \
# 0     241           17      30461       15274  22        1409          711
# 1     212           48      30461       15274  22         616          560
# 2     241           17      33197       10053  10        1409          711
# 3     212           48      33197       10053  10         616          560
# 4     696           88      26462        6953   0         810          292
#
#    ETHNICITY  GENDER  STATUS EMPLOY DATE  HRLY RATE  HRS PER WK  MONTHLY  \
# 0          5       1       8  1988-02-18   75.96150        29.0  9545.82
# 1          5       1       4  2015-02-01   81.04454         4.0  1404.77
# 2          5       1       8  2020-02-01   75.96150        29.0  9545.82
# 3          5       1       4  2018-09-01   81.04453         4.0  1404.77
# 4          3       0       0  2020-06-29    0.00000        40.0  3284.27
#
#    month
# 0      2
# 1      2
# 2      2
# 3      9
# 4      6

# %%
df1["year_of_employment"] = pd.DatetimeIndex(df1['EMPLOY DATE']).year
df1['years_of_service'] = 2020- df1['year_of_employment']

# %%
df1['years_of_service'] = df1['years_of_service'].clip(lower=0)

# %%
df1.drop(columns='EMPLOY DATE',axis=1,inplace=True)

# %%
df1.describe()
# Out:
#               AGENCY    AGENCY NAME      LAST NAME     FIRST NAME  \
# count  149481.000000  149481.000000  149481.000000  149481.000000
# mean      545.736288      60.276202   19719.704725   11177.875469
# std       139.057691      28.849532   11057.849544    6559.968024
# min       101.000000       0.000000       0.000000       0.000000
# 25%       529.000000      40.000000   10541.000000    5276.000000
# 50%       530.000000      54.000000   19547.000000   10441.000000
# 75%       696.000000      88.000000   29650.000000   16796.000000
# max       930.000000     112.000000   38674.000000   23558.000000
#
#                   MI     CLASS CODE    CLASS TITLE      ETHNICITY  \
# count  149481.000000  149481.000000  149481.000000  149481.000000
# mean        7.597929     634.574060     624.022090       3.593253
# std         7.153277     378.480906     404.245777       1.359346
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# # Visualisation

# %% [markdown]
# # Visualisation & Analysis based on Monthly

# %% [markdown]
# Based on sweetviz visuals, we can see that the highest monthly salary is "46,125", lowest monthly salary is "50". The total value of monthly salary is "514.5M" until the year 2020. Highest percentage of people are getting a salary of around "3720.17" and the smallest percentage of people are getting "50.0".

# %%
#lineplot
plt.figure(figsize=(3,3))
sns.lineplot(x='years_of_service',y='MONTHLY',data=df1,ci=None,color='Red')
plt.show()
#histplot
sns.histplot(data=df1,x='MONTHLY')
plt.show()

# %% [markdown]
# Based on the above graphs we can see that the monthly salary highest growth was at "40 years of service", the monthly salary was decreased after "40 years of serivce is completed". Based on the years of service he/she provided we can see the monthly salary growth was started to raise up for them. From the histogram we can say that the most count of people are getting between 0-10000 i.e.,... "6000" people.

# %% [markdown]
# # Analysis about Class title/Role

# %% [markdown]
# Based on the sweetviz report we can see that most percentage of people are working as "CORREC OFFICER V
# " and the least percentage of people are working as "PROGRAM SPECIALIST VII".

# %% [markdown]
# # Showing the Outliers in the salary

# %%
#boxplot
sns.boxplot(data=df,x='MONTHLY')
plt.show()

# %% [markdown]
# Based on the above Boxplot we can say that the outliers started after 20,000(almost 27,000 we assume) monthly salary.

# %% [markdown]
# # Visualisation about Monthly salary based on Role and years of service

# %%
plt.figure(figsize=(15,9))
sns.lineplot(x='years_of_service', y='MONTHLY',hue ='STATUS', data= df1)
plt.legend()
plt.show()

# %% [markdown]
# Based on the above graph we can say the years of service plays a very important role for salary, if the person have more years of service in a role he/she gets more salary and the graph dropped after 40 years which means the retirement age is after 40.

# %%
df1['HRLY RATE']=df1['HRLY RATE'].astype(int)
df1['HRS PER WK']=df1['HRS PER WK'].astype(int)
df1['MONTHLY']=df1['MONTHLY'].astype(int)

# %% [markdown]
# # Scaling The Values

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler object
scaler = StandardScaler()
# Split X and Y
X = df1.drop(columns = ['MONTHLY'],axis=1) # Independent variables
y = df1['MONTHLY'] # Dependent / target variable

# %% [markdown]
# Here we separated all the columns with X and y based on the tasks they asked i.e.,.. X is "everything except salary data" and y is "only salary data". So we can test the X data with y data so that we can get the score and create a model.

# %%
# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to the data
scaler.fit(X, y)

# Transform the data
X_std = scaler.transform(X)

# %% [markdown]
# We fited the data in X and y using StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=101)

# %% [markdown]
# We have to split the X and y into training and testing data so that we can create models.

# %%
X_train
# Out:
#         AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  \
# 78454      530           24      32241        4237   5         257
# 64451      529           40      35264         788  18         284
# 69461      530           24       5106        2679   0         885
# 135375     696           88      37958        3165  13        1094
# 8989       304           16      30240        4107  14         299
# ...        ...          ...        ...         ...  ..         ...
# 87684      601           91      12146       12658   3         278
# 148429     582           85      32585       18096  12         498
# 55293      529           40      25294       14018   4         993
# 49751      529           40      19590        1417  13         935
# 136767     701           92      36737        1165  13         136
#
#         CLASS TITLE  ETHNICITY  GENDER  STATUS  HRLY RATE  HRS PER WK  month  \
# 78454           698          5       0       0          0          40      2
# ...

# %%
X_test
# Out:
#         AGENCY  AGENCY NAME  LAST NAME  FIRST NAME  MI  CLASS CODE  \
# 81830      537           29      14225       10240   0         767
# 51628      529           40      21742        3564   7         993
# 3566       302           54       9351       10053  13        1238
# 24253      405           28      28284        1408   0          19
# 105333     696           88       5908        1553  12         812
# ...        ...          ...        ...         ...  ..         ...
# 76682      530           24      27438        8746   5           9
# 126616     696           88      28849       16846   1         810
# 24309      405           28      28473       22955   8        1213
# 78920      530           24      33645       17796   6         878
# 50671      529           40      20623        9831   3         766
#
#         CLASS TITLE  ETHNICITY  GENDER  STATUS  HRLY RATE  HRS PER WK  month  \
# 81830           904          3       1       0          0          40      1
# ...

# %%
y_train
# Out:
# 78454      4748
# 64451      3775
# 69461      3718
# 135375     3710
# 8989      11430
#           ...
# 87684      5050
# 148429     4023
# 55293      2869
# 49751      3056
# 136767     4956
# Name: MONTHLY, Length: 104636, dtype: int32

# %%
y_test
# Out:
# 81830     5173
# 51628     2829
# 3566      6735
# 24253     3586
# 105333    3906
#           ...
# 76682     2031
# 126616    3480
# 24309     6051
# 78920     3816
# 50671     4866
# Name: MONTHLY, Length: 44845, dtype: int32

# %% [markdown]
# # Model Creation

# %% [markdown]
# # Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression() #model intializtion
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, explained_variance_score, max_error, median_absolute_error
lr_pred = lr.predict(X_test)
lr_r2_score=r2_score(y_test,lr_pred)
print(lr_r2_score)
# Out:
# 0.21992993543917028

# %%
rmse = np.sqrt(mean_squared_error(y_test, lr_pred)) #RSME
print(rmse)
print(mean_squared_error(y_test, lr_pred))
lr.intercept_ #bo
# Out:
# 1839.305877832073
# 3383046.1122276126
# 42146.02923855532

# %%
adjusted_r2 = 1-(1-0.17)*(29897-1)/(29897-12-1)
adjusted_r2
# Out:
# 0.16966671128362998

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, c='blue', marker='o', alpha=0.5, label='Actual (y_test)')
plt.scatter(y_test, lr_pred, c='red', marker='o', alpha=0.5, label='Predicted (lr_pred)')
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (lr_pred)")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the graph we can say most of the predicted values are not even falling on the actual values so we can say this model is not giving a good percentage for prediction.

# %% [markdown]
# # XG Boosting Model

# %%
# !pip install xgboost

# %%
from xgboost import XGBRegressor

# %%
xgb_model = XGBRegressor(max_depth=10,
    n_estimators=1000,
    min_child_weight=0.5,
    colsample_bytree=0.8,
    subsample=0.8,
    eta=0.1,
    seed=42)

# %%
xgb_model.fit(X_train,y_train,eval_metric="rmse",verbose=True)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eta=0.1, eval_metric=None,
#              feature_types=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=10,
#              max_leaves=None, min_child_weight=0.5, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict_train = xgb_model.predict(X_train)
predict_xgb = xgb_model.predict(X_test)

# %%
from sklearn.metrics import explained_variance_score
print(explained_variance_score(predict_xgb,y_test))
# Out:
# 0.8942874351955641

# %%
rmse = np.sqrt(mean_squared_error(y_test, predict_xgb)) #RSME
print(rmse)
print(mean_squared_error(y_test, predict_xgb))
xgb_r2_score=r2_score(y_test, predict_xgb)
print(xgb_r2_score)
# Out:
# 643.5626118429519
# 414172.835362122
# 0.9044991348913263

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, c='blue', marker='o', alpha=0.5, label='Actual (y_test)')
plt.scatter(y_test, predict_xgb, c='red', marker='o', alpha=0.5, label='Predicted (predict_xgb)')
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (predict_xgb)")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the above graphs we can say most of the predicted values are falling on the actual values so this says, this model is good which is giving almost 90% of score. So we can consider this model to predict the salaries.

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
de = DecisionTreeRegressor()

# %%
de.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
de_pred = de.predict(X_test)
de_r2=r2_score(y_test,de_pred)
print(de_r2)
# Out:
# 0.9005323722754309

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

# %%
grid_search = GridSearchCV(de, param_grid, cv=5, scoring='neg_mean_squared_error')

# %%
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [None, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='neg_mean_squared_error')

# %%
best_params = grid_search.best_params_
print(f'Best Hyperparameters: {best_params}')
# Out:
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 10}

# %%
Y_pred = grid_search.best_estimator_.predict(X_test)

# %%
mse = mean_squared_error(y_test, Y_pred)
print(f'Mean Squared Error on Test Set: {mse}')
# Out:
# Mean Squared Error on Test Set: 368169.952762791

# %%
de_r2_score = r2_score(y_test, Y_pred)
print(f'R-squared Score on Test Set: {de_r2_score}')
# Out:
# R-squared Score on Test Set: 0.9151065787182197

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, c='blue', marker='o', alpha=0.5, label='Actual (y_test)')
plt.scatter(y_test, de_pred, c='red', marker='o', alpha=0.5, label='Predicted (de_pred)')
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (de_pred)")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the graph we can say most of the predicted values are almost falling on the actual values so this model is giving a good score with almost 91% percentage which is actually a good score. So we can consider this model for predicting the salaries.

# %% [markdown]
# # KNN Model

# %%
from sklearn.neighbors import KNeighborsRegressor # regression task
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Initialize KNN model
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# Predict on the test set
y_pred = knn.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 3981250.7969414657

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred)) #RSME
print(rmse)
print(mean_squared_error(y_test, y_pred))
knn_r2_score=r2_score(y_test, y_pred)
print(knn_r2_score)
# Out:
# 1995.307193627454
# 3981250.7969414657
# 0.08199460983461926

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, c='blue', marker='o', alpha=0.5, label='Actual (y_test)')
plt.scatter(y_test, y_pred, c='red', marker='o', alpha=0.5, label='Predicted (y_pred)')
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (y_pred)")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the above graph we can say the predicted values are far from the actual values so the model is not giving a good score. So we cant consider this model for predicting the data.

# %% [markdown]
# # Random Forest Model

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf_pred = rf.predict(X_test)
rf_r2_score=r2_score(y_test,rf_pred)
print(rf_r2_score)
# Out:
# 0.9438006678566436

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_test, c='blue', marker='o', alpha=0.5, label='Actual (y_test)')
plt.scatter(y_test, rf_pred, c='red', marker='o', alpha=0.5, label='Predicted (rf_pred)')
plt.xlabel("Actual Values (y_test)")
plt.ylabel("Predicted Values (rf_pred)")
plt.title("Actual vs. Predicted Values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Based on the above graph we can say this model is giving the best score than all the other models so we can consider this model first.

# %% [markdown]
# # Model Presentation

# %%
scores=[lr_r2_score,knn_r2_score,de_r2_score,rf_r2_score,xgb_r2_score]
algorithms=['LinearRegression','KNN','DecisionTree','RandomForest','XGBoosting']
for i in range(len(algorithms)):
    print("The R2 Score acheived using " + algorithms[i] + ' is: ' + str(scores[i])+"%")
# Out:
# The R2 Score acheived using LinearRegression is: 0.21992993543917028%
# The R2 Score acheived using KNN is: 0.08199460983461926%
# The R2 Score acheived using DecisionTree is: 0.9151065787182197%
# The R2 Score acheived using RandomForest is: 0.9438006678566436%
# The R2 Score acheived using XGBoosting is: 0.9044991348913263%

# %%
# plotting the barplot between algoriths and their r2_scores
plt.figure(figsize=(10,6))
plt.xlabel("Algorithms")
plt.ylabel("R2 score")
ax=sns.barplot(x=algorithms,y=scores)
for label in ax.containers:
    ax.bar_label(label)
    plt.xticks(rotation=90)
plt.tight_layout()
plt.tick_params(labelsize=14)

# %% [markdown]
# # Report / Conclusion

# %% [markdown]
# ---
#
# # Project Report: Texas State Government Employee Salary Analysis
#
# ## Overview
#
# The project involved analyzing a dataset containing salary information for positions at all 113 agencies in the Texas state government, spanning from 1988 to 2020. The dataset included 149,481 rows and 21 columns, covering various aspects such as agency, role, ethnicity, gender, and salary details.
#
# ## Tasks
#
# ### Task 1: Data Cleaning and Exploration
#
# 1. **Data Inspection:**
#    - Utilized basic exploratory techniques (`head`, `tail`, `info()`, `describe()`).
#    - Ensured a copy of the original dataset was maintained for preservation.
# 2. **Duplicate Handling:**
#    - Detected and removed duplicate rows.
#
# 3. **Missing Values:**
#    - Checked for missing/null values and we found them in some columns.
#
# 4. **Column Management:**
#    - Removed unnecessary columns: "duplicated," "STATE NUMBER," "hide_from_search," "summed_annual_salary,"        "combined_multiple_jobs," "multiple_full_time_jobs." cause these are having more missing values
#
# 5. **Statistical Analysis:**
#    - Conducted statistical analysis on both numerical and categorical columns.
#
# 6. **Correlation Analysis:**
#    - Utilized a heatmap to identify correlations, focusing on 'HRLY RATE,' 'HRS PER WK,' 'MONTHLY,' 'ANNUAL.'
#
# 7. **Data Visualization:**
#    - Employed Sweetviz for comprehensive data visualization.
#
# ### Task 2: Feature Engineering
#
# 1. **Categorical to Numerical Conversion:**
#    - Utilized label encoding to convert categorical columns.
#
# 2. **Date Formatting:**
#    - Formatted and extracted relevant information from the 'employ date' column.
#
# 3. **Additional Columns:**
#    - Introduced new columns for years of service and years on employment.
#
# ### Task 3: Data Visualization and Analysis
#
# 1. **Salary Trends:**
#    - Explored monthly salary trends using line plots and histograms.
#
# 2. **Outlier Detection:**
#    - Investigated and visualized salary outliers using box plots.
#
# 3. **Role and Experience Analysis:**
#    - Visualized monthly salary based on role and years of experience.
#
# ### Task 4: Predictive Modeling
#
# 1. **Data Scaling:**
#    - Applied standard scaling to the data.
#
# 2. **Model Building:**
#    - Employed multiple regression models (Linear Regression, XGBoost, Decision Tree, KNN, Random Forest).
#
# 3. **Model Evaluation:**
#    - Assessed model performance using R2 scores.
#
# 4. **Hyperparameter Tuning:**
#    - Conducted hyperparameter tuning for the Decision Tree model. We also tried to do for XGBoosting but the dataset is so huge so the execution took more than 3 days and its still running so we didnt added it.
#
# ### Conclusion
#
# - The Random Forest model exhibited the highest R2 score at 94%, indicating strong predictive performance.
# - The project successfully provided insights into salary trends, outliers, and predictive models for Texas state government employee salaries.
